# %% [markdown]
# # Review Lessons 8-11
#
# ### Exercise 1:
# Plot a Radical function:
# $y= \frac{1}{x}$
# Use Exercise 1 in matplotlib.ipynb to help you graph this function.
#
# NOTE: 1/0 is a math error. **x value cannot be 0.**<br>
# HINT: x values should range from -1 to 1. Use 2 arrays that do not include 0 `<br>

# %%
import numpy as np
from matplotlib import pyplot as plt

x_n = np.arange(-1, 0, 0.01)
x_p = -x_n
plt.plot(x_n, 1/x_n)
plt.plot(x_p, 1/x_p)
plt.show()

# %% [markdown]
# ### Exercise 2:
#
# **Linear function:**
# * $y = a(x-h) + k = mx + b$
#
# **Quadratic function:**
# * $y=a(x-h)^2 +k$
#
# **Cubic function:**
# * $y=a(x-h)^3 + k$
#
#
# Ask the user to select between a linear, quadratic or cubic function using an `input` command.
#
# Get a, h and k using an `input` command (look at Review_Lessons1_7)
#
# HINT:
#
# Use `if`, `elif`, `else` to select among the functions.
#
# Expected Output:<br>
# What would you like to plot? L for linear, Q for quadratic, or C for cubic:Q<br>
# What is the value of a?1<br>
# What is the value of h?0<br>
# What is the value of k?0<br>
# ![image.png](attachment:image.png)

# %%
func_type = input("What would you like to plot? L for linear, Q for quadratic, or C for cubic: ")
a = int(input("what is a? "))
h = int(input("what is h? "))
k = int(input("what is k? "))
power = 3
x = np.linspace(-10, 10, 100)
if(func_type == "L"):
    power = 1
elif(func_type == "Q"):
    power = 2
plt.plot(x, a * (x - h) ** power + k)
plt.show()
# Out:
# What would you like to plot? L for linear, Q for quadratic, or C for cubic: Q
# what is a? 1
# what is h? 1
# what is k? 1

# %% [markdown]
# ### Exercise 3:
#
# Can you do Exercise #2 without using an `if`, `elif`,`else` statement.
#
# Hint: You will still use 4 inputs, look at the equations for a different way to determine the power

# %%
power = int(input("what is the power? "))
a = int(input("what is a? "))
h = int(input("what is h? "))
k = int(input("what is k? "))
x = np.linspace(-10, 10, 100)
plt.plot(x, a * (x - h) ** power + k)
plt.show()
# Out:
# what is the power? 4
# what is a? 1
# what is h? 1
# what is k? 1
